# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Import data (bp_primary_energy_consump_by_fuel) and clean data

# %%
energy_consump_by_fuel = pd.read_csv('../../data/Source of Data - BP/bp_primary_energy_consump_by_fuel.csv',skiprows=2)

# %%
pd.set_option('display.max_columns', None)

# %%
energy_consump_by_fuel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Exajoules         87 non-null     object
#  1   Oil               83 non-null     float64
#  2   Natural Gas       83 non-null     object
#  3   Coal              83 non-null     object
#  4   Nuclear energy    83 non-null     object
#  5   Hydro electric    83 non-null     object
#  6   Renew- ables      83 non-null     object
#  7   Total             83 non-null     float64
#  8   Oil.1             83 non-null     float64
#  9   Natural Gas.1     83 non-null     object
#  10  Coal.1            83 non-null     object
#  11  Nuclear energy.1  83 non-null     object
#  12  Hydro electric.1  83 non-null     object
#  13  Renew- ables.1    83 non-null     object
#  14  Total.1           83 non-null     float64
#  15  Unnamed: 15       0 non-null      float64
# ...

# %%
energy_consump_by_fuel.head(2)
# Out:
#   Exajoules   Oil Natural Gas  Coal Nuclear energy Hydro electric  \
# 0       NaN   NaN         NaN   NaN            NaN            NaN
# 1    Canada  4.78        4.24  0.63           0.90           3.38
#
#   Renew- ables  Total  Oil.1 Natural Gas.1 Coal.1 Nuclear energy.1  \
# 0          NaN    NaN    NaN           NaN    NaN              NaN
# 1         0.51  14.45   4.26          4.05   0.50             0.87
#
#   Hydro electric.1 Renew- ables.1  Total.1  Unnamed: 15  Unnamed: 16
# 0              NaN            NaN      NaN          NaN          NaN
# 1             3.42           0.54    13.63          NaN          NaN

# %%
energy_consump_by_fuel.drop([0], axis=0, inplace = True)
energy_consump_by_fuel.head(2)
# Out:
#   Exajoules   Oil Natural Gas  Coal Nuclear energy Hydro electric  \
# 1    Canada  4.78        4.24  0.63           0.90           3.38
# 2    Mexico  3.24        3.17  0.54           0.10           0.21
#
#   Renew- ables  Total  Oil.1 Natural Gas.1 Coal.1 Nuclear energy.1  \
# 1         0.51  14.45   4.26          4.05   0.50             0.87
# 2         0.30   7.55   2.46          3.11   0.21             0.10
#
#   Hydro electric.1 Renew- ables.1  Total.1  Unnamed: 15  Unnamed: 16
# 1             3.42           0.54    13.63          NaN          NaN
# 2             0.24           0.36     6.48          NaN          NaN

# %%
energy_consump_by_fuel.columns
# Out:
# Index(['Exajoules', 'Oil', 'Natural Gas', 'Coal', 'Nuclear energy',
#        'Hydro electric', 'Renew- ables', 'Total', 'Oil.1', 'Natural Gas.1',
#        'Coal.1', 'Nuclear energy.1', 'Hydro electric.1', 'Renew- ables.1',
#        'Total.1', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
energy_consump_by_fuel.rename(columns = {'Oil':'2019 Oil', 'Natural Gas': '2019 Natural Gas', 'Coal': '2019 Coal',
                                            'Nuclear energy':'2019 Nuclear energy', 'Hydro electric': '2019 Hydro electric',
                                            'Renew- ables':'2019 Renewables', 'Total':'2019 Total', 'Oil.1':'2020 Oil', 
                                            'Natural Gas.1':'2020 Natural Gas','Coal.1':'2020 Coal', 'Nuclear energy.1':'2020 Nuclear energy',
                                            'Hydro electric.1':'2020 Hydro electric', 'Renew-ables.1':'2020 Renewables',
                                             'Total.1':'2020 Total'}, inplace = True)

# %%
energy_consump_by_fuel.head(2)
# Out:
#   Exajoules  2019 Oil 2019 Natural Gas 2019 Coal 2019 Nuclear energy  \
# 1    Canada      4.78             4.24      0.63                0.90
# 2    Mexico      3.24             3.17      0.54                0.10
#
#   2019 Hydro electric 2019 Renewables  2019 Total  2020 Oil 2020 Natural Gas  \
# 1                3.38            0.51       14.45      4.26             4.05
# 2                0.21            0.30        7.55      2.46             3.11
#
#   2020 Coal 2020 Nuclear energy 2020 Hydro electric Renew- ables.1  \
# 1      0.50                0.87                3.42           0.54
# 2      0.21                0.10                0.24           0.36
#
#    2020 Total  Unnamed: 15  Unnamed: 16
# 1       13.63          NaN          NaN
# 2        6.48          NaN          NaN

# %%
energy_consump_by_fuel.drop(energy_consump_by_fuel.columns[[15,16]], axis=1, inplace=True)
energy_consump_by_fuel.head(2)
# Out:
#   Exajoules  2019 Oil 2019 Natural Gas 2019 Coal 2019 Nuclear energy  \
# 1    Canada      4.78             4.24      0.63                0.90
# 2    Mexico      3.24             3.17      0.54                0.10
#
#   2019 Hydro electric 2019 Renewables  2019 Total  2020 Oil 2020 Natural Gas  \
# 1                3.38            0.51       14.45      4.26             4.05
# 2                0.21            0.30        7.55      2.46             3.11
#
#   2020 Coal 2020 Nuclear energy 2020 Hydro electric Renew- ables.1  2020 Total
# 1      0.50                0.87                3.42           0.54       13.63
# 2      0.21                0.10                0.24           0.36        6.48

# %%
energy_consump_by_fuel.tail(15)
# Out:
#                                             Exajoules  2019 Oil  \
# 81                                             Taiwan      1.98
# 82                                           Thailand      2.62
# 83                                            Vietnam      1.10
# 84                                 Other Asia Pacific      0.96
# 85                                 Total Asia Pacific     70.67
# 86                                                NaN       NaN
# 87                                        Total World    191.89
# 88                                     of which: OECD     90.16
# 89                                           Non-OECD    101.73
# 90                                    European Union      23.17
# 91                                                NaN       NaN
# 92  Source: statistics are taken from national sta...       NaN
# 93  * In this review, primary energy comprises com...       NaN
# 94  Energy from all sources of non-fossil power ge...       NaN
# ...

# %%
energy_consump_by_fuel=energy_consump_by_fuel.drop(index =[86,91,92,93,94,95])
energy_consump_by_fuel.tail(8)
# Out:
#                            Exajoules  2019 Oil 2019 Natural Gas 2019 Coal  \
# 82                          Thailand      2.62             1.83      0.71
# 83                           Vietnam      1.10             0.35      2.07
# 84                Other Asia Pacific      0.96             0.41      1.23
# 85                Total Asia Pacific     70.67            30.89    122.37
# 87                       Total World    191.89           140.54    157.64
# 88                    of which: OECD     90.16            64.80     32.30
# 89                          Non-OECD    101.73            75.74    125.34
# 90                   European Union      23.17            14.08      7.32
#
#    2019 Nuclear energy 2019 Hydro electric 2019 Renewables  2019 Total  \
# 82                   -                0.06            0.28        5.51
# 83                   -                0.60            0.04        4.17
# 84                   -                0.61            0.01        3.23
# ...
