# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
net_gen_all_sources = pd.read_csv('../data/Source of Data - eia.gov/net_generation_all_sources.csv',skiprows=3)

# %%
pd.set_option('display.max_columns', None)

# %%
net_gen_all_sources.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 16 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Period                                               55 non-null     object
#  1   Coal                                                 48 non-null     object
#  2   Petroleum
# Liquids                                    48 non-null     object
#  3   Petroleum
# Coke                                       48 non-null     object
#  4   Natural
# Gas                                          48 non-null     object
#  5   Other
# Gas                                            48 non-null     object
#  6   Nuclear                                              48 non-null     object
#  7   Hydroelectric
# Conventional                           48 non-null     object
# ...

# %%
net_gen_all_sources.head(2)
# Out:
#           Period       Coal Petroleum\nLiquids Petroleum\nCoke Natural\nGas  \
# 0  Annual Totals        NaN                NaN             NaN          NaN
# 1           2011  1,733,430             16,086          14,096    1,013,689
#
#   Other\nGas  Nuclear Hydroelectric\nConventional  Solar  \
# 0        NaN      NaN                         NaN    NaN
# 1     11,566  790,204                     319,355  1,818
#
#   Renewable\nSources\nExcluding\nHydroelectric and Solar  \
# 0                                                NaN
# 1                                            192,163
#
#   Hydroelectric\nPumped\nStorage   Other  \
# 0                            NaN     NaN
# 1                         -6,421  14,154
#
#   Total Generation at Utility Scale Facilities Estimated Solar Photovoltaic  \
# 0                                          NaN                          NaN
# 1                                    4,100,141                          NaN
#
# ...

# %% [markdown]
# ## Excel file source does not import cleanly
# ### 1. after skipping 3 rows, must add category to each column of data: 11 columns need "utility scale" prepended; 1 needs "small scale" prepended; 2 need "all sources" prepended
# ### 2. table has sections divided by year below annual totals and 12 months rolling totals; determine if any of this data is needed; 'does the data need to be granular to the month?'

# %%
print(net_gen_all_sources.columns)
# Out:
# Index(['Period', 'Coal', 'Petroleum\nLiquids', 'Petroleum\nCoke',
#        'Natural\nGas', 'Other\nGas', 'Nuclear', 'Hydroelectric\nConventional',
#        'Solar', 'Renewable\nSources\nExcluding\nHydroelectric and Solar',
#        'Hydroelectric\nPumped\nStorage', 'Other',
#        'Total Generation at Utility Scale Facilities',
#        'Estimated Solar Photovoltaic', 'Estimated Total Solar Photovoltaic',
#        'Estimated Total Solar'],
#       dtype='object')

# %%
net_gen_all_sources.columns = ['Period', 'Utility Scale Coal', 'Utility Scale Petroleum\nLiquids', 'Utility Scale Petroleum\nCoke',
       'Utility Scale Natural\nGas', 'Utility Scale Other\nGas', 'Utility Scale Nuclear', 'Utility Scale Hydroelectric\nConventional',
       'Utility Scale Solar', 'Utility Scale Renewable\nSources\nExcluding\nHydroelectric and Solar',
       'Utility Scale Hydroelectric\nPumped\nStorage', 'Utility Scale Other',
       'Total Generation at Utility Scale Facilities',
       'Small Scale Estimated Solar Photovoltaic', 'Net Generation Estimated Total Solar Photovoltaic',
       'Net Generation Estimated Total Solar']

# %%
net_gen_all_sources.head(2)
# Out:
#           Period Utility Scale Coal Utility Scale Petroleum\nLiquids  \
# 0  Annual Totals                NaN                              NaN
# 1           2011          1,733,430                           16,086
#
#   Utility Scale Petroleum\nCoke Utility Scale Natural\nGas  \
# 0                           NaN                        NaN
# 1                        14,096                  1,013,689
#
#   Utility Scale Other\nGas Utility Scale Nuclear  \
# 0                      NaN                   NaN
# 1                   11,566               790,204
#
#   Utility Scale Hydroelectric\nConventional Utility Scale Solar  \
# 0                                       NaN                 NaN
# 1                                   319,355               1,818
#
#   Utility Scale Renewable\nSources\nExcluding\nHydroelectric and Solar  \
# 0                                                NaN
# 1                                            192,163
#
# ...

# %%
net_gen_all_sources.drop([0], axis = 0, inplace = True)

# %%
net_gen_all_sources.head(10)
# Out:
#    Period Utility Scale Coal Utility Scale Petroleum\nLiquids  \
# 1    2011          1,733,430                           16,086
# 2    2012          1,514,043                           13,403
# 3    2013          1,581,115                           13,820
# 4    2014          1,581,710                           18,276
# 5    2015          1,352,398                           17,372
# 6    2016          1,239,149                           13,008
# 7    2017          1,205,835                           12,414
# 8    2018          1,149,487                           16,245
# 9    2019            964,957                           11,522
# 10   2020            773,393                            9,662
#
#    Utility Scale Petroleum\nCoke Utility Scale Natural\nGas  \
# 1                         14,096                  1,013,689
# 2                          9,787                  1,225,894
# 3                         13,344                  1,124,836
# ...

# %% [markdown]
# ### 2. table has sections divided by year below annual totals and 12 months rolling totals; determine if any of this data is needed; 'does the data need to be granular to the month?
# # unanswered - decision point
