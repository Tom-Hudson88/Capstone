# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %matplotlib inline

# %%
f = open('../data/Source of Data -caltech.edu/acndata_sessions.json')

# %%
type(f)
# Out:
# _io.TextIOWrapper

# %%
ev_charg_locs = json.load(f)

# %%
ev_charg_locs
# Out:
# {'_meta': {'end': 'Mon, 13 Dec 2021 23:30:00 GMT',
#   'min_kWh': 10,
#   'site': 'caltech',
#   'start': 'Sat, 01 Jan 2011 23:30:00 GMT'},
#  '_items': [{'_id': '5bc90cb9f9af8b0d7fe77cd3',
#    'clusterID': '0039',
#    'connectionTime': 'Wed, 25 Apr 2018 13:45:10 GMT',
#    'disconnectTime': 'Thu, 26 Apr 2018 00:56:16 GMT',
#    'doneChargingTime': 'Wed, 25 Apr 2018 16:44:15 GMT',
#    'kWhDelivered': 10.013,
#    'sessionID': '2_39_95_27_2018-04-25 13:45:09.617470',
#    'siteID': '0002',
#    'spaceID': 'CA-319',
#    'stationID': '2-39-95-27',
#    'timezone': 'America/Los_Angeles',
#    'userID': None,
#    'userInputs': None},
#   {'_id': '5bc90cb9f9af8b0d7fe77cd6',
#    'clusterID': '0039',
#    'connectionTime': 'Wed, 25 Apr 2018 14:40:34 GMT',
#    'disconnectTime': 'Wed, 25 Apr 2018 23:03:12 GMT',
#    'doneChargingTime': 'Wed, 25 Apr 2018 17:40:30 GMT',
#    'kWhDelivered': 10.119,
#    'sessionID': '2_39_79_381_2018-04-25 14:40:33.638896',
#    'siteID': '0002',
# ...

# %%
ev_charg_locs.keys()
# Out:
# dict_keys(['_meta', '_items'])

# %%
ev_charg_locs['_meta'].keys()
# Out:
# dict_keys(['end', 'min_kWh', 'site', 'start'])

# %%
ev_charg_locations = pd.DataFrame.from_dict(ev_charg_locs,orient='columns', dtype=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-72ca598a9747> in <module>
# ----> 1 ev_charg_locations = pd.DataFrame.from_dict(ev_charg_locs,orient='columns', dtype=None)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1371             raise ValueError("only recognize index or columns for orient")
#    1372
# -> 1373         return cls(data, index=index, columns=columns, dtype=dtype)
#    1374
#    1375     def to_numpy(
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ...

# %%
#ev_charg_locations = pd.DataFrame.from_dict(ev_charg_locs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-015496923fff> in <module>
# ----> 1 ev_charg_locations = pd.DataFrame.from_dict(ev_charg_locs)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1371             raise ValueError("only recognize index or columns for orient")
#    1372
# -> 1373         return cls(data, index=index, columns=columns, dtype=dtype)
#    1374
#    1375     def to_numpy(
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ...

# %%
#pd.set_option('display.max_columns', None)

# %%
#renew_gen_by_source.info()

# %%
#renew_gen_by_source.head(2)
