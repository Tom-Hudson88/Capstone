# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
oecd = pd.read_csv('../data/Source of Data - OECD/oecd.csv')

# %%
oecd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17446 entries, 0 to 17445
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    17446 non-null  object
#  1   INDICATOR   17446 non-null  object
#  2   SUBJECT     17446 non-null  object
#  3   MEASURE     17446 non-null  object
#  4   FREQUENCY   17446 non-null  object
#  5   TIME        17446 non-null  int64
#  6   Value       13546 non-null  float64
#  7   Flag Codes  3900 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.1+ MB

# %%
oecd.head(100)
# Out:
#    LOCATION      INDICATOR SUBJECT      MEASURE FREQUENCY  TIME   Value  \
# 0       AUS  PRYENRGSUPPLY     TOT      MLN_TOE         A  1960  31.480
# 1       AUS  PRYENRGSUPPLY     TOT      MLN_TOE         A  1961  32.660
# 2       AUS  PRYENRGSUPPLY     TOT      MLN_TOE         A  1962  34.080
# 3       AUS  PRYENRGSUPPLY     TOT      MLN_TOE         A  1963  35.960
# 4       AUS  PRYENRGSUPPLY     TOT      MLN_TOE         A  1964  37.400
# ..      ...            ...     ...          ...       ...   ...     ...
# 95      AUS  PRYENRGSUPPLY     TOT  TOE_1000USD         A  1994   0.159
# 96      AUS  PRYENRGSUPPLY     TOT  TOE_1000USD         A  1995   0.155
# 97      AUS  PRYENRGSUPPLY     TOT  TOE_1000USD         A  1996   0.159
# 98      AUS  PRYENRGSUPPLY     TOT  TOE_1000USD         A  1997   0.156
# 99      AUS  PRYENRGSUPPLY     TOT  TOE_1000USD         A  1998   0.152
#
#    Flag Codes
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...

# %%
oecd.tail()
# Out:
#         LOCATION      INDICATOR SUBJECT      MEASURE FREQUENCY  TIME  Value  \
# 17441  EU27_2020  PRYENRGSUPPLY     TOT  TOE_1000USD         A  2016  0.082
# 17442  EU27_2020  PRYENRGSUPPLY     TOT  TOE_1000USD         A  2017  0.081
# 17443  EU27_2020  PRYENRGSUPPLY     TOT  TOE_1000USD         A  2018  0.078
# 17444  EU27_2020  PRYENRGSUPPLY     TOT  TOE_1000USD         A  2019  0.076
# 17445  EU27_2020  PRYENRGSUPPLY     TOT  TOE_1000USD         A  2020    NaN
#
#       Flag Codes
# 17441        NaN
# 17442        NaN
# 17443        NaN
# 17444        NaN
# 17445          L
