# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Import data (bp_electricity_generation_by_fuel) and clean data

# %%
bp_electricity_gen_by_fuel = pd.read_csv('../data/Source of Data - BP/bp_electricity_generation_by_fuel.csv',skiprows=2)

# %%
pd.set_option('display.max_columns', None)

# %%
bp_electricity_gen_by_fuel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Terawatt-hours    51 non-null     object
#  1   Oil               47 non-null     object
#  2   Natural Gas       47 non-null     float64
#  3   Coal              47 non-null     object
#  4   Nuclear energy    47 non-null     object
#  5   Hydro electric    47 non-null     object
#  6   Renew- ables      47 non-null     float64
#  7   Other#            47 non-null     object
#  8   Total             47 non-null     float64
#  9   Oil.1             47 non-null     object
#  10  Natural Gas.1     47 non-null     float64
#  11  Coal.1            47 non-null     object
#  12  Nuclear energy.1  47 non-null     object
#  13  Hydro electric.1  47 non-null     object
#  14  Renew- ables.1    47 non-null     float64
#  15  Other#.1          47 non-null     object
# ...

# %%
bp_electricity_gen_by_fuel.head(2)
# Out:
#   Terawatt-hours  Oil  Natural Gas  Coal Nuclear energy Hydro electric  \
# 0            NaN  NaN          NaN   NaN            NaN            NaN
# 1         Canada  3.2         69.5  47.9          100.5          379.7
#
#    Renew- ables Other#  Total Oil.1  Natural Gas.1 Coal.1 Nuclear energy.1  \
# 0           NaN    NaN    NaN   NaN            NaN    NaN              NaN
# 1          47.1    0.7  648.7   3.3           70.9   35.6             97.5
#
#   Hydro electric.1  Renew- ables.1 Other#.1  Total.1  Unnamed: 17  Unnamed: 18
# 0              NaN             NaN      NaN      NaN          NaN          NaN
# 1            384.7            51.2      0.7    643.9          NaN          NaN

# %%
bp_electricity_gen_by_fuel.drop([0], axis=0, inplace = True)

# %%
bp_electricity_gen_by_fuel.head(2)
# Out:
#   Terawatt-hours   Oil  Natural Gas  Coal Nuclear energy Hydro electric  \
# 1         Canada   3.2         69.5  47.9          100.5          379.7
# 2         Mexico  34.8        187.7  32.7           11.4           23.6
#
#    Renew- ables Other#  Total Oil.1  Natural Gas.1 Coal.1 Nuclear energy.1  \
# 1          47.1    0.7  648.7   3.3           70.9   35.6             97.5
# 2          32.3      -  322.6  33.7          183.1   18.9             11.4
#
#   Hydro electric.1  Renew- ables.1 Other#.1  Total.1  Unnamed: 17  Unnamed: 18
# 1            384.7            51.2      0.7    643.9          NaN          NaN
# 2             26.8            39.2        -    313.2          NaN          NaN

# %%
bp_electricity_gen_by_fuel.columns
# Out:
# Index(['Terawatt-hours', 'Oil', 'Natural Gas', 'Coal', 'Nuclear energy',
#        'Hydro electric', 'Renew- ables', 'Other#', 'Total', 'Oil.1',
#        'Natural Gas.1', 'Coal.1', 'Nuclear energy.1', 'Hydro electric.1',
#        'Renew- ables.1', 'Other#.1', 'Total.1', 'Unnamed: 17', 'Unnamed: 18'],
#       dtype='object')

# %%
bp_electricity_gen_by_fuel.rename(columns = {'Oil':'2019 Oil', 'Natural Gas': '2019 Natural Gas', 'Coal': '2019 Coal',
                                            'Nuclear energy':'2019 Nuclear energy', 'Hydro electric': '2019 Hydro electric',
                                            'Renew- ables':'2019 Renewables', 'Other#':'2019 Other#',
                                            'Total':'2019 Total', 'Oil.1':'2020 Oil', 'Natural Gas.1':'2020 Natural Gas',
                                            'Coal.1':'2020 Coal', 'Nuclear energy.1':'2020 Nuclear energy','Hydro electric.1':
                                             '2020 Hydro electric', 'Renew-ables.1':'2020 Renewables', 'Other#.1':'2020 Other#',
                                             'Total.1':'2020 Total'}, inplace = True)

# %%
bp_electricity_gen_by_fuel.head(2)
# Out:
#   Terawatt-hours 2019 Oil  2019 Natural Gas 2019 Coal 2019 Nuclear energy  \
# 1         Canada      3.2              69.5      47.9               100.5
# 2         Mexico     34.8             187.7      32.7                11.4
#
#   2019 Hydro electric  2019 Renewables 2019 Other#  2019 Total 2020 Oil  \
# 1               379.7             47.1         0.7       648.7      3.3
# 2                23.6             32.3           -       322.6     33.7
#
#    2020 Natural Gas 2020 Coal 2020 Nuclear energy 2020 Hydro electric  \
# 1              70.9      35.6                97.5               384.7
# 2             183.1      18.9                11.4                26.8
#
#    Renew- ables.1 2020 Other#  2020 Total  Unnamed: 17  Unnamed: 18
# 1            51.2         0.7       643.9          NaN          NaN
# 2            39.2           -       313.2          NaN          NaN

# %%
bp_electricity_gen_by_fuel.drop(bp_electricity_gen_by_fuel.columns[[17,18]], axis=1, inplace=True)
bp_electricity_gen_by_fuel.head(2)
# Out:
#   Terawatt-hours 2019 Oil  2019 Natural Gas 2019 Coal 2019 Nuclear energy  \
# 1         Canada      3.2              69.5      47.9               100.5
# 2         Mexico     34.8             187.7      32.7                11.4
#
#   2019 Hydro electric  2019 Renewables 2019 Other#  2019 Total 2020 Oil  \
# 1               379.7             47.1         0.7       648.7      3.3
# 2                23.6             32.3           -       322.6     33.7
#
#    2020 Natural Gas 2020 Coal 2020 Nuclear energy 2020 Hydro electric  \
# 1              70.9      35.6                97.5               384.7
# 2             183.1      18.9                11.4                26.8
#
#    Renew- ables.1 2020 Other#  2020 Total
# 1            51.2         0.7       643.9
# 2            39.2           -       313.2

# %%
bp_electricity_gen_by_fuel.tail(10)
# Out:
#                                        Terawatt-hours 2019 Oil  \
# 50                                                NaN      NaN
# 51                                        Total World    820.5
# 52                                     of which: OECD    172.3
# 53                                           Non-OECD    648.2
# 54                                    European Union      49.2
# 55                                                NaN      NaN
# 56  Source: statistics are taken from national sta...      NaN
# 57                            *Based on gross output.      NaN
# 58  # Includes sources not specified elsewhere e.g...      NaN
# 59                                  ^ Less than 0.05.      NaN
#
#     2019 Natural Gas 2019 Coal 2019 Nuclear energy 2019 Hydro electric  \
# 50               NaN       NaN                 NaN                 NaN
# 51            6323.8    9826.2              2796.6              4227.9
# ...

# %%
bp_electricity_gen_by_fuel = bp_electricity_gen_by_fuel.drop(index=[50,55,56,57,58,59])
bp_electricity_gen_by_fuel.tail()
# Out:
#                       Terawatt-hours 2019 Oil  2019 Natural Gas 2019 Coal  \
# 49                Total Asia Pacific    145.1            1497.1    7397.4
# 51                       Total World    820.5            6323.8    9826.2
# 52                    of which: OECD    172.3            3358.6    2450.2
# 53                          Non-OECD    648.2            2965.2    7376.0
# 54                   European Union      49.2             566.7     475.1
#
#    2019 Nuclear energy 2019 Hydro electric  2019 Renewables 2019 Other#  \
# 49               646.9              1791.5           1149.2       114.3
# 51              2796.6              4227.9           2789.2       216.7
# 52              1994.6              1444.2           1599.3       149.1
# 53               802.0              2783.7           1189.9        67.6
# 54               765.5               317.1            658.5        60.3
#
#     2019 Total 2020 Oil  2020 Natural Gas 2020 Coal 2020 Nuclear energy  \
# ...
