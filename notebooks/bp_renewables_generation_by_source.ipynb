# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
renew_gen_by_source = pd.read_csv('../data/Source of Data - BP/bp_renewables_generation_by_source.csv',skiprows=2)

# %%
pd.set_option('display.max_columns', None)

# %%
renew_gen_by_source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Terawatt-hours       90 non-null     object
#  1   Wind                 83 non-null     object
#  2   Solar                83 non-null     object
#  3   Other renewables*    83 non-null     object
#  4   Total                83 non-null     object
#  5   Wind.1               83 non-null     object
#  6   Solar.1              83 non-null     object
#  7   Other renewables*.1  83 non-null     object
#  8   Total.1              83 non-null     object
#  9   Wind.2               83 non-null     object
#  10  Solar.2              83 non-null     object
#  11  Other renewables*.2  83 non-null     object
#  12  Total.2              83 non-null     object
#  13  Unnamed: 13          0 non-null      float64
#  14  Unnamed: 14          0 non-null      float64
# ...

# %%
renew_gen_by_source.head(2)
# Out:
#   Terawatt-hours  Wind Solar Other renewables* Total Wind.1 Solar.1  \
# 0            NaN   NaN   NaN               NaN   NaN    NaN     NaN
# 1         Canada  32.7   4.2              10.3  47.1   36.1     4.4
#
#   Other renewables*.1 Total.1  Wind.2 Solar.2 Other renewables*.2 Total.2  \
# 0                 NaN     NaN     NaN     NaN                 NaN     NaN
# 1                10.7    51.2  10.24%   4.63%               3.93%   8.36%
#
#    Unnamed: 13  Unnamed: 14
# 0          NaN          NaN
# 1          NaN          NaN

# %%
renew_gen_by_source.drop([0], axis=0, inplace = True) 
renew_gen_by_source.head(2)
# Out:
#   Terawatt-hours  Wind Solar Other renewables* Total Wind.1 Solar.1  \
# 1         Canada  32.7   4.2              10.3  47.1   36.1     4.4
# 2         Mexico  16.7   7.4               8.2  32.3   19.7    11.9
#
#   Other renewables*.1 Total.1  Wind.2 Solar.2 Other renewables*.2 Total.2  \
# 1                10.7    51.2  10.24%   4.63%               3.93%   8.36%
# 2                 7.6    39.2  17.49%  60.74%              -7.91%  20.89%
#
#    Unnamed: 13  Unnamed: 14
# 1          NaN          NaN
# 2          NaN          NaN

# %%
renew_gen_by_source.columns
# Out:
# Index(['Terawatt-hours', 'Wind', 'Solar', 'Other renewables*', 'Total',
#        'Wind.1', 'Solar.1', 'Other renewables*.1', 'Total.1', 'Wind.2',
#        'Solar.2', 'Other renewables*.2', 'Total.2', 'Unnamed: 13',
#        'Unnamed: 14'],
#       dtype='object')

# %%
renew_gen_by_source.rename(columns = {'Wind':'2019 Wind','Solar':'2019 Solar','Other renewables':'2019 Other Renewables',
                                      'Total':'2019 Total','Wind.1':'2020 Wind','Solar.1':'2020 Solar','Other renewables#.1':'2020 Other Renewables',
                                     'Total.1':'2020 Total','Wind.2':'2020 Growth Rate Wind','Solar.2':'2020 Growth Rate Solar',
                                      'Other renewables#.2':'2020 Growth Rate Other renewables','Total.2':'2020 Growth Rate Total'}, inplace = True)
renew_gen_by_source.head(2)
# Out:
#   Terawatt-hours 2019 Wind 2019 Solar Other renewables* 2019 Total 2020 Wind  \
# 1         Canada      32.7        4.2              10.3       47.1      36.1
# 2         Mexico      16.7        7.4               8.2       32.3      19.7
#
#   2020 Solar Other renewables*.1 2020 Total 2020 Growth Rate Wind  \
# 1        4.4                10.7       51.2                10.24%
# 2       11.9                 7.6       39.2                17.49%
#
#   2020 Growth Rate Solar Other renewables*.2 2020 Growth Rate Total  \
# 1                  4.63%               3.93%                  8.36%
# 2                 60.74%              -7.91%                 20.89%
#
#    Unnamed: 13  Unnamed: 14
# 1          NaN          NaN
# 2          NaN          NaN

# %%
cols = [13,14]
renew_gen_by_source.drop(renew_gen_by_source.columns[cols], axis=1, inplace=True)

# %%
renew_gen_by_source.head(2)
# Out:
#   Terawatt-hours 2019 Wind 2019 Solar Other renewables* 2019 Total 2020 Wind  \
# 1         Canada      32.7        4.2              10.3       47.1      36.1
# 2         Mexico      16.7        7.4               8.2       32.3      19.7
#
#   2020 Solar Other renewables*.1 2020 Total 2020 Growth Rate Wind  \
# 1        4.4                10.7       51.2                10.24%
# 2       11.9                 7.6       39.2                17.49%
#
#   2020 Growth Rate Solar Other renewables*.2 2020 Growth Rate Total
# 1                  4.63%               3.93%                  8.36%
# 2                 60.74%              -7.91%                 20.89%

# %%
renew_gen_by_source.tail(15)
# Out:
#                                        Terawatt-hours 2019 Wind 2019 Solar  \
# 84                                 Other Asia Pacific       0.5        0.8
# 85                                 Total Asia Pacific     509.4      392.0
# 86                                                NaN       NaN        NaN
# 87                                        Total World    1418.2      707.9
# 88                                     of which: OECD     830.8      378.8
# 89                                           Non-OECD     587.3      329.2
# 90                                    European Union      364.5      125.2
# 91                                                NaN       NaN        NaN
# 92  Source: statistics are taken from national sta...       NaN        NaN
# 93  Based on gross generation and not accounting f...       NaN        NaN
# 94  * Includes electricity generated from: geother...       NaN        NaN
# ...

# %%
renew_gen_by_source = renew_gen_by_source.drop(index=[86,87,88,89,90,91,92,93,94,95,96,97,98])
renew_gen_by_source.tail(8)
# Out:
#         Terawatt-hours 2019 Wind 2019 Solar Other renewables* 2019 Total  \
# 78           Singapore         -        0.2               0.8        1.0
# 79         South Korea       2.7       13.0              14.9       30.5
# 80           Sri Lanka       0.3        0.4               0.1        0.8
# 81              Taiwan       1.9        4.0               2.0        7.9
# 82            Thailand       2.2        4.6              14.6       21.4
# 83             Vietnam         ^        4.1                 ^        4.1
# 84  Other Asia Pacific       0.5        0.8               0.3        1.5
# 85  Total Asia Pacific     509.4      392.0             247.8     1149.2
#
#    2020 Wind 2020 Solar Other renewables*.1 2020 Total 2020 Growth Rate Wind  \
# 78         -        0.3                 0.7        1.0                 0.00%
# 79       3.1       16.6                17.3       37.0                16.87%
# 80       0.6        0.4                 0.1        1.1                95.61%
# ...
