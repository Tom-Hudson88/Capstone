# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
coal_as_fuel = pd.read_csv('../../data/Source of Data - eia.gov/new_csvs/net_generation_for_coal.csv',skiprows=1)

# %%
pd.set_option('display.max_columns', None)

# %%
coal_as_fuel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   description  6 non-null      object
#  1   units        5 non-null      object
#  2   source key   6 non-null      object
#  3   2001         5 non-null      float64
#  4   2002         5 non-null      float64
#  5   2003         5 non-null      float64
#  6   2004         5 non-null      float64
#  7   2005         5 non-null      float64
#  8   2006         5 non-null      float64
#  9   2007         5 non-null      float64
#  10  2008         5 non-null      float64
#  11  2009         5 non-null      float64
#  12  2010         5 non-null      float64
#  13  2011         5 non-null      float64
#  14  2012         5 non-null      float64
#  15  2013         5 non-null      float64
#  16  2014         5 non-null      float64
#  17  2015         5 non-null      float64
# ...

# %%
coal_as_fuel.head(10)
# Out:
#                                    description                   units  \
# 0                  United States : all sectors  thousand megawatthours
# 1               United States : electric power                     NaN
# 2             United States : electric utility  thousand megawatthours
# 3  United States : independent power producers  thousand megawatthours
# 4               United States : all commercial  thousand megawatthours
# 5               United States : all industrial  thousand megawatthours
#
#              source key       2001       2002       2003       2004  \
# 0  ELEC.GEN.COW-US-99.A  1903956.0  1933130.0  1973737.0  1978301.0
# 1  ELEC.GEN.COW-US-98.A        NaN        NaN        NaN        NaN
# 2   ELEC.GEN.COW-US-1.A  1560146.0  1514670.0  1500281.0  1513641.0
# 3  ELEC.GEN.COW-US-94.A   322681.0   395943.0   452433.0   443547.0
# 4  ELEC.GEN.COW-US-96.A      995.0      992.0     1206.0     1340.0
# ...

# %%
coal_as_fuel.drop(coal_as_fuel.columns[2], axis=1, inplace=True)

# %%
coal_as_fuel.head()
# Out:
#                                    description                   units  \
# 0                  United States : all sectors  thousand megawatthours
# 1               United States : electric power                     NaN
# 2             United States : electric utility  thousand megawatthours
# 3  United States : independent power producers  thousand megawatthours
# 4               United States : all commercial  thousand megawatthours
#
#         2001       2002       2003       2004       2005       2006  \
# 0  1903956.0  1933130.0  1973737.0  1978301.0  2012873.0  1990511.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2  1560146.0  1514670.0  1500281.0  1513641.0  1484855.0  1471421.0
# 3   322681.0   395943.0   452433.0   443547.0   507199.0   498316.0
# 4      995.0      992.0     1206.0     1340.0     1353.0     1310.0
#
#         2007       2008       2009       2010       2011       2012  \
# ...

# %%
coal_as_fuel = coal_as_fuel.drop(index=[1,2,3,4,5])

# %%
coal_as_fuel
# Out:
#                    description                   units       2001       2002  \
# 0  United States : all sectors  thousand megawatthours  1903956.0  1933130.0
#
#         2003       2004       2005       2006       2007       2008  \
# 0  1973737.0  1978301.0  2012873.0  1990511.0  2016456.0  1985801.0
#
#         2009       2010       2011       2012       2013       2014  \
# 0  1755904.0  1847290.0  1733430.0  1514043.0  1581115.0  1581710.0
#
#         2015       2016       2017       2018      2019      2020
# 0  1352398.0  1239149.0  1205835.0  1149487.0  964957.0  773393.0

# %%
coal_melted = pd.melt(coal_as_fuel, id_vars=['description','units'], var_name='year', value_name='value')
coal_melted
# Out:
#                     description                   units  year      value
# 0   United States : all sectors  thousand megawatthours  2001  1903956.0
# 1   United States : all sectors  thousand megawatthours  2002  1933130.0
# 2   United States : all sectors  thousand megawatthours  2003  1973737.0
# 3   United States : all sectors  thousand megawatthours  2004  1978301.0
# 4   United States : all sectors  thousand megawatthours  2005  2012873.0
# 5   United States : all sectors  thousand megawatthours  2006  1990511.0
# 6   United States : all sectors  thousand megawatthours  2007  2016456.0
# 7   United States : all sectors  thousand megawatthours  2008  1985801.0
# 8   United States : all sectors  thousand megawatthours  2009  1755904.0
# 9   United States : all sectors  thousand megawatthours  2010  1847290.0
# 10  United States : all sectors  thousand megawatthours  2011  1733430.0
# 11  United States : all sectors  thousand megawatthours  2012  1514043.0
# ...

# %%
coal_melted.to_csv(r'../../data/Source of Data - eia.gov/from_python_csv/coal_melted.csv', index = False)
