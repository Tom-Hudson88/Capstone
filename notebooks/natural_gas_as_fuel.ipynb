# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
natural_gas_as_fuel = pd.read_csv('../../data/Source of Data - eia.gov/new_csvs/net_generation_for_natural_gas.csv',skiprows=1)

# %%
pd.set_option('display.max_columns', None)

# %%
natural_gas_as_fuel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   description  6 non-null      object
#  1   units        5 non-null      object
#  2   source key   6 non-null      object
#  3   2001         5 non-null      float64
#  4   2002         5 non-null      float64
#  5   2003         5 non-null      float64
#  6   2004         5 non-null      float64
#  7   2005         5 non-null      float64
#  8   2006         5 non-null      float64
#  9   2007         5 non-null      float64
#  10  2008         5 non-null      float64
#  11  2009         5 non-null      float64
#  12  2010         5 non-null      float64
#  13  2011         5 non-null      float64
#  14  2012         5 non-null      float64
#  15  2013         5 non-null      float64
#  16  2014         5 non-null      float64
#  17  2015         5 non-null      float64
# ...

# %%
natural_gas_as_fuel.head(10)
# Out:
#                                    description                   units  \
# 0                  United States : all sectors  thousand megawatthours
# 1               United States : electric power                     NaN
# 2             United States : electric utility  thousand megawatthours
# 3  United States : independent power producers  thousand megawatthours
# 4               United States : all commercial  thousand megawatthours
# 5               United States : all industrial  thousand megawatthours
#
#             source key      2001      2002      2003      2004      2005  \
# 0  ELEC.GEN.NG-US-99.A  639129.0  691006.0  649908.0  710100.0  760960.0
# 1  ELEC.GEN.NG-US-98.A       NaN       NaN       NaN       NaN       NaN
# 2   ELEC.GEN.NG-US-1.A  264434.0  229639.0  186967.0  199662.0  238204.0
# 3  ELEC.GEN.NG-US-94.A  290506.0  378044.0  380337.0  427510.0  445625.0
# 4  ELEC.GEN.NG-US-96.A    4434.0    4310.0    3899.0    3969.0    4249.0
# ...

# %%
natural_gas_as_fuel.drop(natural_gas_as_fuel.columns[2], axis=1, inplace=True)

# %%
natural_gas_as_fuel.head(2)
# Out:
#                       description                   units      2001      2002  \
# 0     United States : all sectors  thousand megawatthours  639129.0  691006.0
# 1  United States : electric power                     NaN       NaN       NaN
#
#        2003      2004      2005      2006      2007      2008      2009  \
# 0  649908.0  710100.0  760960.0  816441.0  896590.0  882981.0  920979.0
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#        2010       2011       2012       2013       2014       2015       2016  \
# 0  987697.0  1013689.0  1225894.0  1124836.0  1126609.0  1333482.0  1378307.0
# 1       NaN        NaN        NaN        NaN        NaN        NaN        NaN
#
#         2017       2018       2019       2020
# 0  1296442.0  1469133.0  1585814.0  1624050.0
# 1        NaN        NaN        NaN        NaN

# %%
natural_gas_as_fuel = natural_gas_as_fuel.drop(index=[1,2,3,4,5])

# %%
natural_gas_as_fuel
# Out:
#                    description                   units      2001      2002  \
# 0  United States : all sectors  thousand megawatthours  639129.0  691006.0
#
#        2003      2004      2005      2006      2007      2008      2009  \
# 0  649908.0  710100.0  760960.0  816441.0  896590.0  882981.0  920979.0
#
#        2010       2011       2012       2013       2014       2015       2016  \
# 0  987697.0  1013689.0  1225894.0  1124836.0  1126609.0  1333482.0  1378307.0
#
#         2017       2018       2019       2020
# 0  1296442.0  1469133.0  1585814.0  1624050.0

# %%
natural_gas_melted = pd.melt(natural_gas_as_fuel, id_vars=['description','units'], var_name='year', value_name='value')
natural_gas_melted
# Out:
#                     description                   units  year      value
# 0   United States : all sectors  thousand megawatthours  2001   639129.0
# 1   United States : all sectors  thousand megawatthours  2002   691006.0
# 2   United States : all sectors  thousand megawatthours  2003   649908.0
# 3   United States : all sectors  thousand megawatthours  2004   710100.0
# 4   United States : all sectors  thousand megawatthours  2005   760960.0
# 5   United States : all sectors  thousand megawatthours  2006   816441.0
# 6   United States : all sectors  thousand megawatthours  2007   896590.0
# 7   United States : all sectors  thousand megawatthours  2008   882981.0
# 8   United States : all sectors  thousand megawatthours  2009   920979.0
# 9   United States : all sectors  thousand megawatthours  2010   987697.0
# 10  United States : all sectors  thousand megawatthours  2011  1013689.0
# 11  United States : all sectors  thousand megawatthours  2012  1225894.0
# ...

# %%
natural_gas_melted.to_csv(r'../../data/Source of Data - eia.gov/from_python_csv/natural_gas_melted.csv', index = False)
